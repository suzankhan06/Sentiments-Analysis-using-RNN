# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = ['th glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good']

# %%
sent
# Out:
# ['th glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
# define the vocaublary size

voc_size = 10000

# %%
#One hot Representation

one_hot_repr=[one_hot(words, voc_size)for words in sent]
one_hot_repr
# Out:
# [[6589, 6888, 7971, 7573],
#  [2536, 6888, 7971, 4210],
#  [2536, 3186, 7971, 8595],
#  [2296, 5511, 4340, 9627, 4129],
#  [2296, 5511, 4340, 9627, 4773],
#  [1406, 2536, 5769, 7971, 5710],
#  [1351, 2405, 8579, 9627]]

# %%
## Word embedding represeantiaon

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedding_docs = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length)
print(embedding_docs)
# Out:
# [[   0    0    0    0 6589 6888 7971 7573]
#  [   0    0    0    0 2536 6888 7971 4210]
#  [   0    0    0    0 2536 3186 7971 8595]
#  [   0    0    0 2296 5511 4340 9627 4129]
#  [   0    0    0 2296 5511 4340 9627 4773]
#  [   0    0    0 1406 2536 5769 7971 5710]
#  [   0    0    0    0 1351 2405 8579 9627]]

# %%
## feature representation

dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_length))
model.compile('adam', 'mse')
# Out:
# WARNING:tensorflow:From c:\Users\suzan\Desktop\Udemy\Gen_AI_with_LangChain\rnn\env\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\suzan\Desktop\Udemy\Gen_AI_with_LangChain\rnn\env\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedding_docs)
# Out:
# 1/1 [==============================] - 0s 175ms/step
# array([[[-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.03776361,  0.00303459,  0.00775552, -0.01311588,
#          -0.03098042, -0.01155533, -0.00453621,  0.04013263,
#           0.02039916,  0.01025737],
#         [-0.0186693 ,  0.04114541, -0.00819697, -0.01361016,
#          -0.03590513, -0.03144963,  0.01965162,  0.01876125,
#           0.02555425,  0.03525552],
#         [ 0.02474042, -0.01688683, -0.04310663, -0.04976571,
#          -0.03656035, -0.04355909,  0.00393884,  0.0056561 ,
#           0.03155358,  0.04664836],
#         [ 0.02776103,  0.04869503, -0.00779097, -0.04371176,
#          -0.03254879, -0.00047308, -0.01857303, -0.00462563,
#           0.04167429,  0.03133674]],
#
#        [[-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.04761695, -0.01299812, -0.03367902,  0.03450773,
#          -0.01254905, -0.00445936,  0.03272654, -0.01817084,
#          -0.00365762, -0.02366528],
#         [-0.0186693 ,  0.04114541, -0.00819697, -0.01361016,
#          -0.03590513, -0.03144963,  0.01965162,  0.01876125,
#           0.02555425,  0.03525552],
#         [ 0.02474042, -0.01688683, -0.04310663, -0.04976571,
#          -0.03656035, -0.04355909,  0.00393884,  0.0056561 ,
#           0.03155358,  0.04664836],
#         [-0.00129968, -0.03966471,  0.04300667,  0.00709885,
#           0.00053401,  0.02485306, -0.01188471,  0.02432015,
#          -0.01039566,  0.01824233]],
#
#        [[-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.04761695, -0.01299812, -0.03367902,  0.03450773,
#          -0.01254905, -0.00445936,  0.03272654, -0.01817084,
#          -0.00365762, -0.02366528],
#         [-0.02287789,  0.01718661, -0.03953118, -0.02380511,
#           0.00456442, -0.01506985, -0.04562145, -0.02310933,
#          -0.00228741, -0.01837071],
#         [ 0.02474042, -0.01688683, -0.04310663, -0.04976571,
#          -0.03656035, -0.04355909,  0.00393884,  0.0056561 ,
#           0.03155358,  0.04664836],
#         [-0.0329787 , -0.04556763, -0.0034364 , -0.03312467,
#           0.02460105,  0.01712309, -0.02133294,  0.01019617,
#           0.00794423, -0.04960451]],
#
#        [[-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [ 0.03394227,  0.0492262 , -0.00967748, -0.04433006,
#           0.00572429,  0.0277766 ,  0.04959292, -0.01158903,
#          -0.02279009,  0.03991193],
#         [-0.00519204, -0.02892357,  0.03310568,  0.00553864,
#           0.02606409, -0.0468993 , -0.01077654, -0.00574524,
#          -0.0069206 , -0.01862738],
#         [-0.04953647, -0.03541995, -0.02145828,  0.03519091,
#           0.04816261, -0.004617  , -0.03527815, -0.04862999,
#           0.01806312, -0.03330852],
#         [-0.02962551, -0.02165294,  0.04334729, -0.04262743,
#           0.00292934, -0.00655049, -0.00424099,  0.04589317,
#           0.00275296,  0.02063144],
#         [ 0.03947767, -0.00464249, -0.03324912,  0.0467947 ,
#          -0.0475928 ,  0.0421911 ,  0.01300013,  0.03248957,
#          -0.0197695 ,  0.00092477]],
#
#        [[-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [ 0.03394227,  0.0492262 , -0.00967748, -0.04433006,
#           0.00572429,  0.0277766 ,  0.04959292, -0.01158903,
#          -0.02279009,  0.03991193],
#         [-0.00519204, -0.02892357,  0.03310568,  0.00553864,
#           0.02606409, -0.0468993 , -0.01077654, -0.00574524,
#          -0.0069206 , -0.01862738],
#         [-0.04953647, -0.03541995, -0.02145828,  0.03519091,
#           0.04816261, -0.004617  , -0.03527815, -0.04862999,
#           0.01806312, -0.03330852],
#         [-0.02962551, -0.02165294,  0.04334729, -0.04262743,
#           0.00292934, -0.00655049, -0.00424099,  0.04589317,
#           0.00275296,  0.02063144],
#         [ 0.02709151, -0.02063531,  0.03476484, -0.0101463 ,
#           0.00622617, -0.02705591, -0.02214369, -0.0025438 ,
#          -0.02650794,  0.03733982]],
#
#        [[-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.00968269, -0.00653088,  0.01804518,  0.0289999 ,
#          -0.04348192,  0.01112907,  0.00999401, -0.04749583,
#          -0.03117477, -0.01881284],
#         [-0.04761695, -0.01299812, -0.03367902,  0.03450773,
#          -0.01254905, -0.00445936,  0.03272654, -0.01817084,
#          -0.00365762, -0.02366528],
#         [-0.03714633,  0.03354857, -0.01706672,  0.03535669,
#          -0.03548225,  0.02292613, -0.03790997,  0.03875716,
#           0.01183339,  0.04070884],
#         [ 0.02474042, -0.01688683, -0.04310663, -0.04976571,
#          -0.03656035, -0.04355909,  0.00393884,  0.0056561 ,
#           0.03155358,  0.04664836],
#         [ 0.00067232, -0.02960711,  0.02731309, -0.02240077,
#          -0.02490352, -0.03388051,  0.03708286,  0.04271049,
#           0.03852762, -0.0373954 ]],
#
#        [[-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.02292688, -0.00102898,  0.00842119, -0.01332179,
#          -0.01860904,  0.01048303,  0.03133813,  0.04871185,
#          -0.0468028 ,  0.03530524],
#         [-0.0238256 , -0.01421402, -0.01361684,  0.03624735,
#           0.03454614,  0.03364111, -0.00133222, -0.04638182,
#           0.00373154,  0.01323886],
#         [ 0.04548806,  0.01714338,  0.04381334, -0.02445871,
#          -0.04375976,  0.02430836,  0.00664508, -0.02219466,
#           0.04012403,  0.03238427],
#         [-0.02690272,  0.04367859,  0.00264336, -0.04932058,
#           0.04533875, -0.02819245,  0.01920474, -0.00206342,
#          -0.02843454, -0.02183734],
#         [-0.02962551, -0.02165294,  0.04334729, -0.04262743,
#           0.00292934, -0.00655049, -0.00424099,  0.04589317,
#           0.00275296,  0.02063144]]], dtype=float32)

# %%
#chckc first sentence

embedding_docs[0]
# Out:
# array([   0,    0,    0,    0, 6589, 6888, 7971, 7573])

# %%
model.predict(embedding_docs[0])
# Out:
# 1/1 [==============================] - 0s 36ms/step
# array([[-0.02292688, -0.00102898,  0.00842119, -0.01332179, -0.01860904,
#          0.01048303,  0.03133813,  0.04871185, -0.0468028 ,  0.03530524],
#        [-0.02292688, -0.00102898,  0.00842119, -0.01332179, -0.01860904,
#          0.01048303,  0.03133813,  0.04871185, -0.0468028 ,  0.03530524],
#        [-0.02292688, -0.00102898,  0.00842119, -0.01332179, -0.01860904,
#          0.01048303,  0.03133813,  0.04871185, -0.0468028 ,  0.03530524],
#        [-0.02292688, -0.00102898,  0.00842119, -0.01332179, -0.01860904,
#          0.01048303,  0.03133813,  0.04871185, -0.0468028 ,  0.03530524],
#        [-0.03776361,  0.00303459,  0.00775552, -0.01311588, -0.03098042,
#         -0.01155533, -0.00453621,  0.04013263,  0.02039916,  0.01025737],
#        [-0.0186693 ,  0.04114541, -0.00819697, -0.01361016, -0.03590513,
#         -0.03144963,  0.01965162,  0.01876125,  0.02555425,  0.03525552],
#        [ 0.02474042, -0.01688683, -0.04310663, -0.04976571, -0.03656035,
#         -0.04355909,  0.00393884,  0.0056561 ,  0.03155358,  0.04664836],
#        [ 0.02776103,  0.04869503, -0.00779097, -0.04371176, -0.03254879,
#         -0.00047308, -0.01857303, -0.00462563,  0.04167429,  0.03133674]],
#       dtype=float32)
